# %%
import pandas as pd
import numpy as np
from scipy import stats, integrate
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns; sns.set()
from plotly import graph_objects as go
# %matplotlib inline

# %%
data=pd.read_excel('../usedata/2016/UK domiciled leavers in employment 201617.xlsx')
data
# Out:
#    Table 12a - UK domiciled leavers in employment within the UK by level of qualification obtained, region of domicile and region of employment 2016/17  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                            Domicile
# 3                                                 NaN
# 4                                        Postgraduate
# ..                                                ...
# 66                                                NaN
# 67                                                NaN
# 68  This work is licensed under a Creative Commons...
# 69                            Published by HESA, 2018
# 70                                     www.hesa.ac.uk
#
#                  Unnamed: 1  Unnamed: 2                Unnamed: 3  \
# 0                       NaN         NaN                       NaN
# 1   UK region of employment         NaN                       NaN
# 2                North East  North West  Yorkshire and The Humber
# 3                       NaN         NaN                       NaN
# 4                       NaN         NaN                       NaN
# ..                      ...         ...                       ...
# 66                      NaN         NaN                       NaN
# 67                      NaN         NaN                       NaN
# 68                      NaN         NaN                       NaN
# 69                      NaN         NaN                       NaN
# 70                      NaN         NaN                       NaN
#
#        Unnamed: 4     Unnamed: 5       Unnamed: 6 Unnamed: 7  Unnamed: 8  \
# 0             NaN            NaN              NaN        NaN         NaN
# 1             NaN            NaN              NaN        NaN         NaN
# 2   East Midlands  West Midlands  East of England     London  South East
# 3             NaN            NaN              NaN        NaN         NaN
# 4             NaN            NaN              NaN        NaN         NaN
# ..            ...            ...              ...        ...         ...
# 66            NaN            NaN              NaN        NaN         NaN
# 67            NaN            NaN              NaN        NaN         NaN
# 68            NaN            NaN              NaN        NaN         NaN
# 69            NaN            NaN              NaN        NaN         NaN
# 70            NaN            NaN              NaN        NaN         NaN
#
#     Unnamed: 9             Unnamed: 10    Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 0          NaN                     NaN            NaN         NaN         NaN
# 1          NaN                     NaN            NaN         NaN         NaN
# 2   South West  England region unknown  Total England       Wales    Scotland
# 3          NaN                     NaN            NaN         NaN         NaN
# 4          NaN                     NaN            NaN         NaN         NaN
# ..         ...                     ...            ...         ...         ...
# 66         NaN                     NaN            NaN         NaN         NaN
# 67         NaN                     NaN            NaN         NaN         NaN
# 68         NaN                     NaN            NaN         NaN         NaN
# 69         NaN                     NaN            NaN         NaN         NaN
# 70         NaN                     NaN            NaN         NaN         NaN
#
#          Unnamed: 14                           Unnamed: 15        Unnamed: 16  \
# 0                NaN                                   NaN                NaN
# 1                NaN                                   NaN                NaN
# 2   Northern Ireland  Guernsey, Jersey and the Isle of Man  UK region unknown
# 3                NaN                                   NaN                NaN
# 4                NaN                                   NaN                NaN
# ..               ...                                   ...                ...
# 66               NaN                                   NaN                NaN
# 67               NaN                                   NaN                NaN
# 68               NaN                                   NaN                NaN
# 69               NaN                                   NaN                NaN
# 70               NaN                                   NaN                NaN
#
#    Unnamed: 17
# 0          NaN
# 1          NaN
# 2   Total \nUK
# 3          NaN
# 4          NaN
# ..         ...
# 66         NaN
# 67         NaN
# 68         NaN
# 69         NaN
# 70         NaN
#
# [71 rows x 18 columns]
